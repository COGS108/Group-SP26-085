# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report section Title & Abstract trhough Data Wrangling:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#
# For the report section Data Visualizations through Documentation and Written Communication:
# - Each Developing  => -1 pts
# - Each Unsatisfactory/Missing => -2 pts
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# Until the score is 0
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Ethics                                                                             | No effort or just says we have no ethical concerns                                                                                                                                                                                                                                                  | Minimal ethical section; probably just talks about data privacy and no unintended consequences discussion. Ethical concerns raised seem irrelevant.                                                                                                                                                 | The ethical concerns described are appropriate and sufficiently                                                                                                                                                                                                                                                                     | Ethical concerns are described clearly and succinctly. This was clearly a thorough and nuanced approach to the issues                                                                                                                                                                                                          |
# | Data visualizations                                                                | No plots. Or most plots don't capture useful information, or their display of information is difficult to understand. Legends, labels, axes, titles, captions, etc of most plots may be poor or missing. Most figures are not referenced in the main text.                                          | Fewer than 3 relevant plots (irrelevant to the question plots do not count).  Or a few of the plots don't make sense or capture useful information. Legends, labels, axes, titles, captions, etc are illegible or inadequately describe the content in a few figures. Or a few figures are not referenced or explained inside the main text. | Plots almost all make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | No analyses beyond EDA style explorations of the dataset. Or analyses presented do not help address the question/hypothesis. Or most of the analyses presented are not technically approriate (eg. using parametric methods for non-parametric data).                                              | Only one analysis beyond EDA. Or a few analyses presented do not address the question/hypothesis. Or a few of the analyses presented are not technically approriate                                                                                                                                                                  |  At least two analyses beyond EDA. That is, the project uses two different techniques (e.g., inference vs machine learning; or t-test vs regression; or entire dataset vs stratified) or two different proxies for the same concept are investigated.  Each analysis addressed the question/hypothesis and is technically approriate. | Many different analyses are used. Each analysis addressed an aspect of the question/hypothesis and is technically approriate. Perhaps they use multiple datasets, or do something else to go the extra mile and address the reliability of the results                                            |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # Housing Policy and Homelessness: Examining the Impact of Zoning Restrictions in the United States (2015–2024)
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.
#
# Our group wanted to analyze a topic that was relevant and useful surrounding urban planning in America, leading us to choose the topic on the relationship between zoning restrictiveness and homelessness rates. To investigate the strength in relationship between zoning, homelessness, and housing prices, this project investigates four main datasets: U.S Census Population Estimates, HUD Homelessness Counts, FHFA House Price index, and National Zoning and Land Use.
#
# Homelessness in the United States has increased significantly over the past decade, which has led researchers and policymakers to investigate how the housing markets and land-use regulations in driving homelessness rates. This project examined whether states with more restrictive housing policies through measures like zoning restrictivness, housing supply constraints, and housing market indicators. Our data was over a ten year time period 2015 and 2024. We also investigated whether this relationship became stronger over time as housing costs continued to rise over the years.
#
# To answer this research question, we combined state-level data on homelessness, zoning restrictiveness, housing prices, population trends, and migration patterns into a panel dataset covering 49 states over ten years. We conducted exploratory data analysis and then estimated several statistical models, including bivariate OLS regression, multivariate pooled OLS with controls, and random effects panel regression. These models allowed us to evaluate the independent effect of zoning restrictions while accounting for housing prices, regional differences, migration, and pandemic related disruptions.
#
# Our initial analysis suggested that states with more restrictive zoning policies tended to have higher homelesseness rates. However, after controlling for housing prices and other factors, the relationship between zoning restrictiveness and homelessness was no longer statistically significant. Instead, housing prices emerged as the strongest and most consistent predictor of homelessness across all models. States in the western United States also exhibited a considerably higher homelessness rates than other regions.
#
# Overall, our findings suggest that restrictive zoning policies may influence homelessness indirectly by contributing to higher housing costs rather than applying a direct effect on homelessness rates. The results support existing research that identifies housing affordability as a major contributor to homelessness and indicates that policies aimed to increase housing afforadbility and supply may be more effective than solely focusing on zoning restrictions.

# %% [markdown]
# ## Authors
# - Anay Takkallapalli: Background research, Project administration, Data Curation
# - Faith Chang: Background Research, Data Curation, Writing - original draft
# - Gaurika Agarwal : Conceptualization, Methodology, Writing - original draft
# - Lauren Ta: Data Curation, Writing - original draft
# - Kashika Sharma: Conceptualization, Data Curation, Writing - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# Between 2015 and 2024, did U.S. states with more restrictive housing policies— characterized by higher zoning restrictiveness scores, lower housing permit issuance, and slower housing construction growth — experience higher per capita homelessness rates than states with more permissive housing policies, characterized by lower zoning restrictiveness scores, higher permit issuance, and greater housing supply growth? Additionally, did this relationship strengthen over time as housing costs increased?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Homelessness in the United States has become one of the most prevalent and pressing issues of the 21st century. In early 2024, homelessness reached an all time high of over 700,000 unhoused people which is the largest number since the Housing and Urban Development (HUD) started tracking this. Many people have attributed homelessness to factors at an individual level such as mental illnesses, drug addiction, or unemployment. However, recently there has been a growing body of research that points to structural housing market conditions being a primary factor in the rise of homelessness. In particular, in the book Homelessness is a Housing Problem, Gregg Colburn and Clayton Page Aldern systematically tested a range of conventional explanations, including drug use, poverty rates, weather, whether certain cities offered more protections, and they found that none of these explained why homelessness rates vary across U.S. cities.<sup><a href="#ref1">1</a></sup> Instead, they found that housing market conditions such as cost and availability of rental units were a far more convincing predictor. This finding structures the homelessness problem as a housing supply problem rather than a social services issue.
#
# One of the biggest connectors of housing markets to homelessness is housing costs or the burden of paying rent. The Pew Charitable Trusts compared homelessness and rent data across U.S. metro areas in 2017 and 2022 and found that homelessness is consistently high in cities where rents were also high. The data showed that rent growth slowed and homeless rates declined in those cities. When examining some of these cities that experienced higher rent costs, they found that Austin, a city that experienced around 15 percent growth in housing supply could not keep up with the 22% in housing demand due to the restrictive measures of zoning laws.<sup><a href="#ref2">2</a></sup> These trends motivate our research question because if rising housing costs worsen the homelessness crisis, and zoning laws restrict housing supply which increases housing costs, then it is logical to assume that restrictive zoning laws affect homeless rates, in times of steep rent growth.
#
# Restrictive zoning laws, which include limits to multifamily housing, minimum lot sizes, and height restrictions, are often believed to be the reason for the strain on housing supply and increasing cost, which contributes to the rise of homelessness in large cities. The growing research field investigating how land use regulation affects housing availability and affordability across American cities. For example, economists Joseph Gyourko and Raven Molloy found that metropolitan areas with stricter land regulations tend to have significantly higher housing prices because supply cannot meet the demand.<sup><a href="#ref3">3</a></sup> Since homelessness is closely correlated with housing affordability, this source provides the foundation for studying whether restrictive zoning laws correlate with higher per-capita homelessness. Correspondingly, research comparing metropolitan regions has shown that homelessness rates are substantially higher in more expensive housing markets. This suggests that housing constraints play a factor in homelessness, and it is not just at the individual level.<sup><a href="#ref4">4</a></sup> These findings lay the foundation for our project in examining zoning restrictiveness and how it correlates with homelessness in different cities.
#
# Recent work has directly linked zoning, housing supply, and homelessness outcomes. Homelessness rates across U.S. metropolitan areas are examined, and conclude that regions with tighter housing markets and more constrained development, which is usually tied to zoning rules, consistently demonstrate higher homelessness rates when compared to cities with more flexible housing supply. These new developments emphasize factors like rent levels, vacancy rates, and construction limits instead of individual ones, suggesting that restrictive zoning increases homelessness because of the lack of new housing. In addition to this research, the California Legislative Analyst's Office found that areas with higher housing costs because of constraints experience higher rates of homelessness, particularly in coastal California cities.<sup><a href="#ref5">3</a></sup> These studies will support our hypothesis that zoning restrictions and homelessness are related and not mutually exclusive.
#
# The prior work we have examined only focuses on either cross-sectional comparisons or data on a single city, which leaves us to answer the question of the relationship between homelessness and restrictive zoning laws in other states. We will also examine a specific time period between 2015 and 2024. During this time, housing costs increased in many U.S. areas, and zoning reforms expanded into some cities but not others. Studies show that supply constraints result in demand, which increases housing prices. This suggests that when housing markets tighten, homelessness rises due to the high cost of shelter. Building on previous research, our project will compare U.S. cities with different zoning restrictiveness levels and evaluate whether homelessness per capita is wider or narrower when compared with housing prices, which are a cause of zoning restrictions. By combining longitudinal data with cross-city comparisons, our analysis will include prior work as context, along with detailed data from 2015 to 2025.
#
# ---
#
# **References**
#
# <a name="ref1">1</a>. ^ Colburn, G., & Aldern, C. P. (2022). *Homelessness Is a Housing Problem: How Structural Factors Explain U.S. Patterns.* University of California Press. https://homelessnesshousingproblem.com
#
# <a name="ref2">2</a>. ^ The Pew Charitable Trusts. (2023). *How Housing Costs Drive Levels of Homelessness.* https://www.pew.org/en/research-and-analysis/articles/2023/08/22/how-housing-costs-drive-levels-of-homelessness
#
# <a name="ref3">3</a>. ^ Gyourko, J., & Molloy, R. (2015). *Regulation and Housing Supply.* Handbook of Regional and Urban Economics. https://www.sciencedirect.com/handbook/handbook-of-regional-and-urban-economics/vol/5/suppl/C
#
# <a name="ref4">4</a>. ^ Byrne, T., Treglia, D., Culhane, D., Kuhn, R., & Kane, V. (2016). Predictors of Homelessness Across U.S. Communities. *Housing Policy Debate.* https://ideas.repec.org/a/taf/houspd/v26y2016i1p252-275.html
#
# <a name="ref5">5</a>. ^ California Legislative Analyst's Office. (2015). *California's High Housing Costs: Causes and Consequences.* https://lao.ca.gov/reports/2015/finance/housing-costs/housing-costs.aspx

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict a significant positive relationship between housing supply constraints and per capita homelessness rates across U.S. states from 2015 to 2024. Specifically, states with more restrictive housing policies — characterized by higher zoning restrictiveness scores, lower housing permit issuance rates, and slower housing construction growth — are expected to experience higher homelessness rates than states with more permissive housing policies. We also hypothesize that this relationship will strengthen over time as housing costs continue to rise. Based on prior research, stricter land-use regulations can limit housing supply, increase housing prices, and contribute to higher rates of homelessness in expensive housing markets.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Below is the processed and cleaned dataset, merging our four original datasets:
# - U.S. Census County Population Estimates
# - FHFA Annual County House Price Index
# - National Zoning and Land Use Database
# - HUD Point-in-Time Homelessness Counts by State
#
# Due to its length, wrangling steps and summary for each dataset can be found in previous checkpoints (`01-DataCheckpoint.ipynb`).

# %% [markdown]
# ### Final Merged and Cleaned Overall Dataset

# %%
import pandas as pd
df = pd.read_csv('data/02-processed/merged_final.csv')
df.head()
# Out:
#   state  year  number_of_cocs  overall_homeless  overall_homeless___under_18  \
# 0    AK  2015             2.0            1956.0                          411
# 1    AL  2015             8.0            3970.0                          716
# 2    AR  2015             7.0            2560.0                          417
# 3    AZ  2015             3.0            9896.0                         2124
# 4    CA  2015            43.0          115738.0                        13657
#
#    overall_homeless___age_18_to_24  overall_homeless___over_24_standardized  \
# 0                              197                                     1348
# 1                              271                                     2983
# 2                              243                                     1900
# 3                              824                                     6948
# 4                            11645                                    90436
#
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your EDA feedback
#
# **NOTE** The final report should not be overly long.  If this EDA step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any EDA you later decided was unecessary side quest.
# 2) if the code to EDA is very long (in either lines or in time to compute) make sure you write out images of the EDA into `results/` and reload them as images here instead of recalculating it. And make a statement here like "To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`."
#
# To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`. Below are saved figures found in `results/`.

# %% [markdown]
# ### First Analysis You Did - Give it a better title
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model
#
# **NOTE** The final report should not be overly long.  If this analysis step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any analysis you later decided was unecessary side quest before checking in for the final hand in
# 2) if the code to do an analysis is very long (in either lines or in time to compute) put it in a different file.  In that file make write out results of analysis into `results/` and reload the results here instead of recalculating it. And make a statement here like "To see the code responsible for analyses see `path/to/some-file-name.ipynb_or.py`."

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ### Correlational Analysis: Zoning Restrictiveness vs. Homelessness Rate Scatterplot
# To directly examine the relationship between our variables, we produced a scatterplot plotting each state's average zoning restrictiveness score against its average homelessness rate per 100,000 residents, averaged across 2015–2024. Points are sized by state population and colored by Census region to reveal whether geographic patterns drive the relationship. A linear regression line is overlaid to assess the direction and strength of the association, with the correlation coefficient and p-value reported to evaluate statistical significance. This plot serves as an initial test of the project's core hypothesis: that states with more restrictive housing policies experience higher per capita homelessness rates

# %%
from IPython.display import Image, display
display(Image(filename='results/zoning_vs_homelessness_scatter.png', width=800))

# %% [markdown]
# ### Takeaway
# The scatterplot shows a weak positive relationship between zoning restrictiveness and homelessness (r = 0.15, p = 0.297). The most striking pattern is that nearly all states cluster near zero on the zoning axis, with a handful of Western states (CA, OR, WA) spreading rightward with high restriction scores. DC and NY sit at the extreme upper-left — very high homelessness despite low zoning scores — suggesting factors beyond zoning are driving their rates. The wide vertical scatter at low zoning scores (most of the dataset) makes the regression line unreliable, which explains the non-significant p-value. The regional color pattern is notable: orange (West) states tend to appear at higher zoning scores, while green (South) and blue (Midwest) states cluster at the bottom-left with low restriction and low homelessness. This regional separation is what motivated region fixed effects in the model — without them, the zoning coefficient would partly reflect the West Coast effect rather than policy itself.

# %% [markdown]
# ### Dual-line HPI vs Homeless Trends
#
# To visualize the relationship between Housing Price Index (HPI) and Homelessness, we employ a dual y-axis line chart to map both trends simultaneously. The EDA highlights a strong positive Pearson correlation coefficient (r=0.70) between average HPI and homelessness per 100k population. This demonstrates that rising housing costs are a direct driver of housing instability and homelessness.
#
# Aggregating the data across a 10-year timeline visually captures how shifts in the real estate market closely match shifts in population-adjusted homelessness rates.
#
# These results align with our hypothesis.

# %%
display(Image(filename='results/dual_line_hpi_homelessness.png', width=800))

# %% [markdown]
# ### Time-Series Analysis: Homelessness Over Time by Housing Policy
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model

# %%
display(Image(filename='results/homelessness_rates_over_time_line.png', width=800))

# %% [markdown]
# ### Geographic Distribution of Homelessness and Zoning Restrictiveness
# We produced two choropleth maps using state-level averages across 2015–2024. The first map displays homelessness rates per 100,000 residents by state, while the second displays average zoning restrictiveness scores. Viewing these maps side by side allows for a visual comparison of whether states with stricter housing policies tend to cluster in the same regions as states with higher homelessness rates.

# %%
display(Image(filename='results/choropleth_homelessness.png', width=800))
display(Image(filename='results/choropleth_zoning.png', width=800))

# %% [markdown]
# ### Takeaway
#
# The two maps show a notable geographic overlap. High homelessness (Image 1) is concentrated in the West Coast (CA, OR, WA), Hawaii, and New York, with the South and Midwest showing consistently low rates. The zoning restrictiveness map (Image 2) mirrors this pattern — Washington leads in restriction score, with CA, NV, CO, and parts of the Northeast also showing elevated scores, while the entire South and Midwest are near-white.
#
# The overlap is imperfect in two important ways. Hawaii has extreme homelessness but relatively low measured zoning scores, suggesting climate and housing cost factors independent of formal zoning policy. New York has very high homelessness but also low restriction scores, likely reflecting urban density dynamics not captured by the NZLUD zoning index. These exceptions reinforce why zoning alone may not be sufficient enough to explain the high number of homeless population in the west coast.

# %% [markdown]
# ## Setup for Modeling
#
# We load the merged state-year panel (490 obs: 49 states × 10 years, DC dropped as a structural outlier with homelessness rates 4× the next-highest state). Six features are engineered before modeling: the outcome (`homeless_per_100k`) is log-transformed to reduce right skew from CA/HI; `year` is mean-centred to prevent multicollinearity with the interaction term; a `zoning × year_c` interaction term is constructed to test whether the zoning effect strengthens over time; `net_mig` is normalised by population to a per-1,000 rate; a `covid` dummy flags the 2020–2021 pandemic shock visible in the EDA time-series; and Census regions are one-hot encoded as fixed effects to absorb the West Coast geographic clustering identified in the choropleth maps.

# %%
# install packages
# %pip install linearmodels -q
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.diagnostic import het_breuschpagan
from linearmodels.panel import RandomEffects, PooledOLS
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, KFold
import warnings
warnings.filterwarnings('ignore')

# ── Load data ─────────────────────────────────────────────────────────────────
df = pd.read_csv('data/02-processed/merged_final.csv')
df = df[df['state'] != 'DC'].copy()   # drop DC — extreme structural outlier

# ── Outcome: log-transform to reduce right skew ───────────────────────────────
df['log_homeless_per_100k'] = np.log(df['homeless_per_100k'])

# ── Centred year: prevents multicollinearity in interaction model ─────────────
df['year_c'] = df['year'] - df['year'].mean()

# ── Interaction term: zoning × centred year ───────────────────────────────────
df['zoning_x_year'] = df['avg_total_restrictions'] * df['year_c']

# ── Net migration rate (per 1,000 residents) ─────────────────────────────────
df['net_mig_rate'] = df['net_mig'] / df['pop'] * 1_000

# ── COVID shock dummy ─────────────────────────────────────────────────────────
df['covid'] = df['year'].isin([2020, 2021]).astype(int)

# ── Region fixed effect dummies ───────────────────────────────────────────────
region_labels = {1: 'Northeast', 2: 'Midwest', 3: 'South', 4: 'West'}
df['region_name'] = df['REGION'].map(region_labels)
df = pd.get_dummies(df, columns=['region_name'], drop_first=True)
region_fe_cols = [c for c in df.columns if c.startswith('region_name_')]

print(f"Dataset: {df.shape[0]} obs | {df['state'].nunique()} states | years {sorted(df['year'].unique())}")
print("\nOutcome variable summary:")
print(df[['homeless_per_100k', 'log_homeless_per_100k']].describe().round(3))
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Dataset: 490 obs | 49 states | years [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Outcome variable summary:
#        homeless_per_100k  log_homeless_per_100k
# count            490.000                490.000
# mean             151.355                  4.835
# std              111.977                  0.564
# min               21.238                  3.056
# 25%               87.276                  4.469
# 50%              107.688                  4.679
# 75%              159.218                  5.070
# max              810.968                  6.698

# %% [markdown]
# ## Step 1: OLS Baseline (Bivariate)
# We begin with a bivariate OLS baseline regressing log homelessness on zoning restrictiveness alone, with cluster-robust standard errors grouped by state to account for serial correlation across years within each state. This replicates the EDA scatterplot (r = 0.15, p = 0.297) as a formal regression and sets a benchmark R² to beat once controls are added.

# %%
X1 = sm.add_constant(df['avg_total_restrictions'])
model1 = sm.OLS(df['log_homeless_per_100k'], X1).fit(
    cov_type='cluster', cov_kwds={'groups': df['state']}
)

print(model1.summary2())

# Convert coefficient to interpretable % effect
b_zoning = model1.params['avg_total_restrictions']
pct_change = (np.exp(b_zoning) - 1) * 100
print(f"\nInterpretation: 1-unit increase in zoning → {pct_change:.1f}% change in homeless/100k")
print(f"R²: {model1.rsquared:.4f}  |  p-value: {model1.pvalues['avg_total_restrictions']:.4f}")
# Out:
#                    Results: Ordinary least squares
# ...
# Model:              OLS                   Adj. R-squared:     0.116
# Dependent Variable: log_homeless_per_100k AIC:                770.4619
# Date:               2026-06-11 01:08      BIC:                778.8507
# No. Observations:   490                   Log-Likelihood:     -383.23
# Df Model:           1                     F-statistic:        12.04
# Df Residuals:       488                   Prob (F-statistic): 0.00111
# R-squared:          0.118                 Scale:              0.28095
# ----------------------------------------------------------------------
#                           Coef.  Std.Err.    z    P>|z|  [0.025 0.975]
# ----------------------------------------------------------------------
# const                     4.7407   0.0771 61.5010 0.0000 4.5896 4.8917
# avg_total_restrictions    0.5786   0.1668  3.4692 0.0005 0.2517 0.9056
# ----------------------------------------------------------------------
# ...

# %% [markdown]
# ### Takeaway
# The bivariate baseline explains 11.8% of variance in log homelessness (R² = 0.118). The zoning coefficient is positive and statistically significant (β = 0.579, p = 0.0005), meaning a one-unit increase in average zoning restrictiveness is associated with a 78.4% increase in homelessness per 100k. However, this result should be interpreted cautiously — with only one predictor, the coefficient is almost certainly inflated by omitted variable bias. States with high zoning scores also tend to have high housing prices and sit on the West Coast, so the zoning coefficient is absorbing the combined effect of all three. The large skew and significant Jarque-Bera statistic confirm the residuals are non-normal, reinforcing the need for the log transformation and motivating the addition of controls in Step 2.

# %% [markdown]
# ## Step 2: Pooled OLS with Full Controls and Region Fixed Effects
#
# The main inferential model adds `avg_hpi`, `net_mig_rate`, a `covid` dummy, a linear year trend, and region fixed effects as controls, isolating the zoning coefficient from the confounders identified in the EDA. Cluster-robust standard errors are again grouped by state. A Breusch-Pagan test is run to confirm whether heteroskedasticity is present and whether the robust SEs are necessary.

# %%
formula_controls = (
    "log_homeless_per_100k ~ "
    "avg_total_restrictions + "
    "avg_hpi + "
    "net_mig_rate + "
    "covid + "
    "year_c + "
    + " + ".join(region_fe_cols)
)

model2 = smf.ols(formula_controls, data=df).fit(
    cov_type='cluster', cov_kwds={'groups': df['state']}
)
print(model2.summary2())

# ── Breusch-Pagan test for heteroskedasticity ─────────────────────────────────
bp_stat, bp_pval, _, _ = het_breuschpagan(model2.resid, model2.model.exog)
print(f"\nBreusch-Pagan: stat={bp_stat:.3f}, p={bp_pval:.4f}")
print("→ p < 0.05 confirms heteroskedasticity; cluster-robust SEs are appropriate"
      if bp_pval < 0.05 else "→ Homoskedastic; standard SEs would also be valid")

# ── Readable coefficient table ────────────────────────────────────────────────
key_vars = ['avg_total_restrictions', 'avg_hpi', 'net_mig_rate', 'covid', 'year_c']
coef_df = pd.DataFrame({
    'Coef'  : model2.params[key_vars].round(4),
    'SE'    : model2.bse[key_vars].round(4),
    'p-val' : model2.pvalues[key_vars].round(4),
    '% effect': ((np.exp(model2.params[key_vars]) - 1) * 100).round(2),
    'Sig'   : ['***' if p < 0.01 else '**' if p < 0.05 else
               '*' if p < 0.10 else ''
               for p in model2.pvalues[key_vars]]
})
print("\nKey Coefficients:")
print(coef_df.to_string())
# Out:
#                        Results: Ordinary least squares
# ...
# Model:                 OLS                     Adj. R-squared:       0.500
# Dependent Variable:    log_homeless_per_100k   AIC:                  498.5466
# Date:                  2026-06-11 01:08        BIC:                  536.2963
# No. Observations:      490                     Log-Likelihood:       -240.27
# Df Model:              8                       F-statistic:          16.09
# Df Residuals:          481                     Prob (F-statistic):   3.08e-11
# R-squared:             0.508                   Scale:                0.15903
# -----------------------------------------------------------------------------
#                                Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -----------------------------------------------------------------------------
# Intercept                      4.3824   0.1165 37.6083 0.0000  4.1540  4.6108
# ...

# %% [markdown]
# ### Takeaway
# Adding controls more than quadruples the explained variance (R² = 0.508), confirming that the bivariate result was heavily confounded. The picture changes substantially for zoning: once HPI and region are held constant, the zoning coefficient collapses to near zero and becomes statistically insignificant (β = −0.088, p = 0.696). This is the key finding of the model — zoning does not have a direct independent effect on homelessness after controlling for housing prices. The most likely explanation is mediation: zoning raises prices, and prices raise homelessness, but zoning itself has no additional effect once prices are accounted for.
#
# The significant predictors tell a clearer story. Housing prices are the primary driver — a one-point increase in HPI is associated with a 0.08% increase in homelessness per 100k (β = 0.0007, p = 0.023), which compounds meaningfully across the large HPI range in the dataset. Being in the West adds a 78% homelessness premium over the South baseline (β = 0.581, p = 0.001), capturing the structural West Coast effect identified in the choropleth maps. Notably, the covid coefficient is negative and highly significant (β = −0.176, p < 0.001), meaning 2020–2021 homelessness counts were actually 16% *lower* than the trend predicted — likely reflecting eviction moratoriums and emergency shelter expansions temporarily suppressing measured homelessness during those years.
#
# The Breusch-Pagan test confirms heteroskedasticity (p < 0.001), validating the use of cluster-robust standard errors. The high condition number (2,389) flags multicollinearity, most likely between `avg_hpi` and the region dummies given that Western states dominate the high-HPI range — this does not bias the coefficients but widens standard errors, making it harder to detect a zoning effect even if one exists.

# %% [markdown]
# ## Step 3: Random Effects Panel Model
#
# We use a Random Effects (RE) model rather than Fixed Effects because `avg_total_restrictions` is time-invariant — it does not change year-to-year within states, so state fixed effects would absorb it entirely. RE instead uses both within- and between-state variation to estimate the zoning coefficient while partially controlling for unobserved state heterogeneity. The dataset is restructured to a `(state, year)` MultiIndex as required by `linearmodels`, and standard errors are clustered by state.

# %%
panel_df = df.set_index(['state', 'year'])

re_vars = ['avg_total_restrictions', 'avg_hpi', 'net_mig_rate',
           'covid', 'year_c'] + region_fe_cols

Y_panel = panel_df['log_homeless_per_100k']
X_panel = sm.add_constant(panel_df[re_vars])

# Fit Random Effects model with entity-clustered standard errors
re_model   = RandomEffects(Y_panel, X_panel)
re_results = re_model.fit(cov_type='clustered', cluster_entity=True)
print(re_results.summary)

# ── Compare pooled R² vs RE R² (overall) ─────────────────────────────────────
pooled = PooledOLS(Y_panel, X_panel)
pooled_res = pooled.fit(cov_type='clustered', cluster_entity=True)

print(f"\nPooled OLS  R² (benchmark) : {pooled_res.rsquared:.4f}")
print(f"Random Effects R² (overall): {re_results.rsquared:.4f}")
print(f"Random Effects R² (between): {re_results.rsquared_between:.4f}")
print(f"Random Effects R² (within) : {re_results.rsquared_within:.4f}")

# ── Variance decomposition: how much of total variance is between-state? ──────
theta = re_results.theta.mean().item()
print(f"\nTheta (RE weight, 0=pooled, 1=FE): {theta:.4f}")
print("→ Values near 0 mean between-state variance dominates (good for RE)")
# Out:
#                           RandomEffects Estimation Summary
# ...
# Dep. Variable:     log_homeless_per_100k   R-squared:                        0.2874
# Estimator:                 RandomEffects   R-squared (Between):              0.5372
# No. Observations:                    490   R-squared (Within):               0.2491
# Date:                   Thu, Jun 11 2026   R-squared (Overall):              0.5015
# Time:                           01:08:16   Log-likelihood                    145.82
# Cov. Estimator:                Clustered
#                                            F-statistic:                      24.251
# Entities:                             49   P-value                           0.0000
# Avg Obs:                         10.0000   Distribution:                   F(8,481)
# Min Obs:                         10.0000
# Max Obs:                         10.0000   F-statistic (robust):             18.036
# ...

# %% [markdown]
# ### Takeaway
# The RE model tells a consistent story with Step 2. Zoning remains insignificant (β = −0.123, p = 0.602), HPI is the dominant driver (β = 0.0009, p < 0.001), and the West region premium holds (β = 0.540, p = 0.001). The covid dummy is again negative and significant, confirming the pandemic suppression effect.
#
# The R² decomposition is the most informative output here. The between-state R² of 0.537 means the model explains 54% of the variation in average homelessness *across* states — which is the relevant metric for the research question. The within-state R² of 0.249 captures how well the model tracks year-to-year changes *within* individual states, which is lower since zoning doesn't vary over time and contributes nothing to within-state dynamics.
#
# Theta = 0.853 indicates the RE estimator is weighting heavily toward the Fixed Effects end of the spectrum, meaning there is substantial unobserved state heterogeneity in the data. This is expected given how different states are structurally, and reinforces that the between-state zoning variation — not within-state changes — is doing all the explanatory work. The consistency of the zoning coefficient across Steps 2 and 3 (both near zero, both insignificant) strengthens confidence that the null result for zoning is genuine rather than a modelling artefact.

# %% [markdown]
# ## Step 4: Interaction Model (Zoning x Year)
# We extend the Random Effects (RE) model by adding an interaction between avg_total_restrictions and a centered year variable (year_c) to directly test whether the relationship between zoning restrictions and homelessness changes over time. A positive interaction coefficient indicates that the association between zoning restrictions and homelessness becomes stronger over time, while a negative coefficient suggests the relationship weakens. Centering the year variable reduces multicollinearity and allows the main zoning coefficient to be interpreted at the average year in the sample. The data remain structured as a (state, year) MultiIndex and standard errors are clustered by state.

# %%
interaction_vars = ['avg_total_restrictions','year_c','zoning_x_year','avg_hpi','net_mig_rate','covid'] + region_fe_cols

Y_panel = panel_df['log_homeless_per_100k']
X_panel = sm.add_constant(panel_df[interaction_vars])

interaction_model = RandomEffects(Y_panel, X_panel)
interaction_results = interaction_model.fit(cov_type='clustered', cluster_entity=True)

print(interaction_results.summary)

# ── Marginal Effect of Zoning Over Time ──────────────────────────────────────
b_zoning = interaction_results.params['avg_total_restrictions']
b_interaction = interaction_results.params['zoning_x_year']

years = [2015, 2018, 2021, 2024]

print("\nMarginal Effect of Zoning Restrictions")

for yr in years:
    yr_c = yr - df['year'].mean()
    effect = b_zoning + b_interaction * yr_c
    print(f"Year {yr}: {effect:.4f}")
# Out:
#                           RandomEffects Estimation Summary
# ...
# Dep. Variable:     log_homeless_per_100k   R-squared:                        0.2874
# Estimator:                 RandomEffects   R-squared (Between):              0.5373
# No. Observations:                    490   R-squared (Within):               0.2500
# Date:                   Thu, Jun 11 2026   R-squared (Overall):              0.5017
# Time:                           01:08:16   Log-likelihood                    146.60
# Cov. Estimator:                Clustered
#                                            F-statistic:                      21.512
# Entities:                             49   P-value                           0.0000
# Avg Obs:                         10.0000   Distribution:                   F(9,480)
# Min Obs:                         10.0000
# Max Obs:                         10.0000   F-statistic (robust):             16.529
# ...

# %% [markdown]
# ### Takeaway
#
# The interaction between zoning restrictions and year is positive but not statistically significant (β = 0.0072, p = 0.644). While the estimated effect of zoning restrictions becomes slightly less negative over time, there is insufficient evidence to conclude that the relationship between zoning restrictions and homelessness changed meaningfully during the study period. Overall, the results suggest that the association between zoning restrictions and homelessness remained relatively stable from 2015 to 2024.

# %% [markdown]
# ## Step 5: Random Forest + Ridge CV Nonlinear Benchmark
#
# The previous models focus on estimating and interpreting the relationship between zoning restrictions and homelessness under a linear specification. As a robustness check, we compare their predictive performance against two machine learning models: Ridge Regression and Random Forest Regression. Ridge Regression allows for coefficient shrinkage and improved out-of-sample prediction while retaining a linear structure, whereas Random Forest can capture nonlinear relationships and complex interactions without requiring them to be specified a priori. Five-fold cross-validation is used to evaluate predictive performance. Comparing these models to the Random Effects specification provides insight into how much predictive power may be left unexplained by linear assumptions, while Random Forest feature importance highlights which variables contribute most to prediction.

# %%
# ── Use same covariates as RE model (excluding interaction term) ─────────────
ml_vars = ['avg_total_restrictions','avg_hpi','net_mig_rate','covid','year_c'] + region_fe_cols

X = df[ml_vars]
y = df['log_homeless_per_100k']

# ── Ridge Regression: regularized linear benchmark ───────────────────────────
ridge_pipeline = Pipeline([('scaler', StandardScaler()),('ridge', Ridge(alpha=1.0))])

cv = KFold(n_splits=5, shuffle=True, random_state=42)

# ── Five-fold cross-validation ───────────────────────────────────────────────
ridge_scores = cross_val_score(ridge_pipeline, X, y, cv=cv, scoring='r2')

# ── Random Forest: nonlinear benchmark ───────────────────────────────────────
rf = RandomForestRegressor(n_estimators=500, min_samples_leaf=3, random_state=42)

rf_scores = cross_val_score(rf, X, y, cv=cv, scoring='r2')

# ── Compare predictive performance results across the models ──────────────────
print(f"\nRandom Effects R²     : {re_results.rsquared:.4f}")
print(f"Ridge CV Mean R²      : {ridge_scores.mean():.4f}")
print(f"Random Forest CV Mean : {rf_scores.mean():.4f}")

rf.fit(X, y)

importance_df = (pd.DataFrame({'feature': X.columns,'importance': rf.feature_importances_}).sort_values('importance', ascending=False))

print(importance_df)
# Out:
# Random Effects R²     : 0.2874
# Ridge CV Mean R²      : 0.4742
# Random Forest CV Mean : 0.7202
#                   feature  importance
# 1                 avg_hpi    0.246918
# 0  avg_total_restrictions    0.199657
# 7        region_name_West    0.183912
# 2            net_mig_rate    0.178852
# 5   region_name_Northeast    0.092356
# 4                  year_c    0.045325
# 6       region_name_South    0.039107
# 3                   covid    0.013874

# %% [markdown]
# ### Takeaway
#
# The Random Forest model substantially outperforms both the Random Effects and Ridge models (R² ≈ 0.72 vs. 0.29 and 0.47), indicating that homelessness is driven by important nonlinear relationships and interactions that linear specifications miss. The strongest predictors are housing prices (HPI), housing restrictions, and net migration, followed by persistent regional differences—especially in the West. Overall, the results suggest that structural housing market conditions and geography are the primary drivers, rather than time shocks like COVID or simple linear trends.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > We have considered that homelessness data (for example, HUD Point-in-Time counts) could potentially undercount certain populations, such as homeless individuals outside of homeless shelters at the time of data collection (making them harder to track). To address this, we will utilize and compare multiple datasets when possible and be careful when interpreting our results.
#
#  - [ ] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > We realize that homelessness disproportionately affects certain demographic groups. While our main analysis is at the city level, we will try to incorporate demographic data (e.g., race, income, etc) where available to be able to better understand potential disparities and avoid any misleading conclusions.
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > The data used in this project will only be stored for the length of the course. After the project is done, the data will be deleted from personal devices and shared platforms unless needed for academic purposes. Since the data is publicly available, it can be accessed again if necessary.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > We realize that our analysis may not fully capture the lived experiences of individuals affected by homelessness. While we are using quantitative city-level data, we will be mindful of these limitations and avoid making hasty, broad conclusions. We'll also rely on existing research and reports to help us better understand the context behind the data as well as the nuances that come with it.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We understand that our datasets may contain biases, such as undercounting in homelessness data (as mentioned earlier) and differences in how cities report information. There may also be other factors (like income, population size, cost of living, etc) that influence homelessness but are not fully captured. To address this, we will include relevant control variables when possible and will make sure to interpret our results carefully.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > We will make sure that our visualizations and summaries accurately reflect the data by using appropriate scaling, clearly labeled axes, and avoiding any misleading formatting. We will do our best to present results as transparently as we can, and include any limitations so that our findings are not misinterpreted.
#
#  - [ ] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > We will make sure that our analysis is reproducible by clearly documenting our data sources, cleaning steps, and methods. All our code will be organized and commented so that others can follow along and replicate our results as needed.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > Our analysis could include variables like housing costs and geographic location, which could indirectly reflect factors like income or race. We will be careful when interpreting these relationships and avoid making conclusions that link homelessness to demographic traits instead of broader housing and policy factors.
#
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We will use statistical methods like correlation and regression to evaluate relationships. In addition to statistical significance, we'll consider effect sizes and real world implications to avoid redundancy of weak or insignificant relationships.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > We will use interpretable models like linear and logistic regression so relationships between zoning, housing costs, and homelessness can be clearly explained to both technical and general audiences.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We plan to clearly communicate that our findings represent correlations rather than causation because the two are not inverse relationships. We also will acknowledge limitations like omitted variables, potential bias in homelessness counts, and differences in reporting across cities.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# > If our findings were used to inform policy decisions, it would be crucial to review the outcomes and include feedback from communities affected by homelessness to prevent harm and misinterpretation.
#
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > We acknowledge that our findings could be misused to oversimplify the causes of homelessness or justify any ineffective or harmful policies. In order to mitigate this, we'll present results with proper context and emphasize that homelessness is influenced by multiple structural and individual factors.

# %% [markdown]
# ## Discussion and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
